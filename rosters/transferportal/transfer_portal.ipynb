# %%
import pandas as pd

# %%
df = pd.read_csv("transfer_portal.csv")
display(df)
# Out:
#               fullName  jerseyNum  height position    classYr teamMarketTo  \
# 0     O'Mariyah Tucker       10.0    71.0        G     Senior          NaN
# 1         Kimora Fagan        NaN     NaN      NaN        NaN          NaN
# 2         Claudia Diez       15.0    75.0        F  Sophomore          NaN
# 3       Justina Graham       11.0    71.0        F     Senior          NaN
# 4     Sharmayne Finley       20.0    70.0        G     Senior          NaN
# ...                ...        ...     ...      ...        ...          ...
# 1413   Aizhanique Mayo        NaN     NaN      NaN        NaN       DePaul
# 1414   Lika Kvirkvelia       13.0    76.0        F   Freshman          UAB
# 1415  Candace Kpetikou        3.0    75.0        F   Freshman   Miami (FL)
# 1416    Jovana Nikolić        NaN     NaN      NaN        NaN   Lindenwood
# 1417       Fia Proctor        4.0    74.0        F   Freshman    Seattle U
#
# ...
